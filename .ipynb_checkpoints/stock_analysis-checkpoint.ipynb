# %%
import pandas as pd
import os
import time
from datetime import datetime

from time import mktime

# %matplotlib notebook
import matplotlib
import matplotlib.pylab as plt
# import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')

import re

# %%
def Key_Stats(gather="Total Debt/Equity (mrq)"):
    statspath = os.getcwd()+'/intraQuarter/_KeyStats'
    stock_list = [x[0] for x in os.walk(statspath)]
    #print (stock_list)
    
    stock_list_2 = []
    for root, dirs, files in os.walk(statspath):
        dirs.sort()
        for dirname in dirs:
            temp = os.path.join(root, dirname)
            #print(os.path.join(root, dirname),'\n')
            stock_list_2.append(temp)
    print(stock_list_2)
    
    df = pd.DataFrame(columns = ['Date',
                                 'Unix',
                                 'Ticker',
                                 'DE Ratio',
                                 'Price',
                                 'stock_p_change',
                                 'SP500',
                                 'sp500_p_change',
                                 'Difference'])
    
    sp500_df = pd.DataFrame.from_csv('YAHOO_INDEX_GSPC.csv')
    
    ticker_list = []
    
    for each_dir in stock_list_2[1:25]:
        each_file = sorted(os.listdir(each_dir))
        ticker = each_dir.split('/_KeyStats/')[1]
        ticker_list.append(ticker)
        
        starting_stock_value = False
        starting_sp500_value = False
        
        if len(each_file) > 0:
            for file in each_file:
                date_stamp = datetime.strptime(file, '%Y%m%d%H%M%S.html')
                unix_time = time.mktime(date_stamp.timetuple())

                full_file_path = each_dir+'/'+file

                source = open(full_file_path,'r').read()

                try:
                    value = float(source.split(gather+':</td><td class="yfnc_tabledata1">')[1].split('</td>')[0])
                    try:
                        sp500_date = datetime.fromtimestamp(unix_time).strftime('%Y-%m-%d')
                        row = sp500_df[(sp500_df.index == sp500_date)]
                        sp500_value = float(row["Adj Close"])
                    except:
                        sp500_date = datetime.fromtimestamp(unix_time-259200).strftime('%Y-%m-%d')
                        # 259200 = 3days in second, get out of weekend
                        row = sp500_df[(sp500_df.index == sp500_date)]
                        sp500_value = float(row["Adj Close"])
                        
                    stock_price = float(source.split('</small><big><b>')[1].split('</b></big>')[0])
                    print('stock_price:',stock_price,'ticker:',ticker)
                    
                    if not starting_stock_value:
                        starting_stock_value = stock_price
                    if not starting_sp500_value:
                        starting_sp500_value = sp500_value
                    
                    stock_p_change = ((stock_price - starting_stock_value) / starting_stock_value) * 100
                    sp500_p_change = ((sp500_value - starting_sp500_value) / starting_sp500_value) * 100
                    
                    df = df.append({'Date':date_stamp,
                                    'Unix':unix_time,
                                    'Ticker':ticker,
                                    'DE Ratio':value,
                                    'Price':stock_price,
                                    'stock_p_change':stock_p_change,
                                    'SP500':sp500_value,
                                    'sp500_p_change':sp500_p_change,
                                    'Difference':stock_p_change - sp500_p_change}, ignore_index = True)
                except Exception as e:
                    pass
    
    for each_ticker in ticker_list:
        try:
            plot_df = df[(df['Ticker'] == each_ticker)]
            plot_df = plot_df.set_index(['Date'])
            
            plot_df['Difference'].plot(label=each_ticker)
            plt.legend()
            
        except:
            pass
    
    plt.show()
    
    save = gather.replace(' ','').replace(')','').replace('(','').replace('/','')+'.csv'
    print(save)
    df.to_csv(save)
print('ok')
# Out:
# ok

# %%
Key_Stats()
# Out:
# ['/home/xander/github/stock-analysis/intraQuarter/_KeyStats/a', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aa', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aapl', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/abbv', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/abc', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/abt', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/ace', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aci', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/acn', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/act', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/adbe', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/adi', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/adm', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/adp', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/adsk', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/adt', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aee', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aeo', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aep', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aes', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aet', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/afl', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/agn', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aig', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aiv', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aiz', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/akam', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/all', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/altr', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/alxn', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/amat', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/amd', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/amgn', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/amp', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/amt', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/amzn', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/an', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/anf', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/ann', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aon', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/apa', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/apc', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/apd', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aph', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/apol', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/arg', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/arna', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/aro', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/ati', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/atvi', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/avb', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/avp', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/avy', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/axp', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/azo', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/ba', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/bac', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/bax', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/bbby', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/bbry', '/home/xander/github/stock-analysis/intraQuarter/_KeyStats/bbt', '/home/xander/github/sto ...
# stock_price: 8.15 ticker: aa
# stock_price: 32.86 ticker: aa
# stock_price: 33.58 ticker: aa
# stock_price: 34.26 ticker: aa
# stock_price: 29.43 ticker: aa
# stock_price: 27.45 ticker: aa
# stock_price: 8.06 ticker: aa
# stock_price: 38.08 ticker: aa
# stock_price: 32.89 ticker: aa
# stock_price: 28.04 ticker: aa
# stock_price: 40.34 ticker: aa
# stock_price: 39.04 ticker: aa
# stock_price: 29.37 ticker: aa
# stock_price: 9.04 ticker: aa
# stock_price: 31.46 ticker: aa
# stock_price: 34.75 ticker: aa
# stock_price: 29.1 ticker: aa
# stock_price: 10.35 ticker: aa
# stock_price: 20.85 ticker: aapl
# stock_price: 76.04 ticker: aapl
# stock_price: 62.68 ticker: aapl
# stock_price: 71.94 ticker: aapl
# stock_price: 22.32 ticker: aapl
# stock_price: 38.59 ticker: aapl
# stock_price: 71.11 ticker: aapl
# stock_price: 28.92 ticker: aapl
# stock_price: 30.3 ticker: aapl
# stock_price: 44.86 ticker: aapl
# stock_price: 77.81 ticker: aapl
# stock_price: 57.01 ticker: abc
# stock_price: 54.9 ticker: abc
# stock_price: 58.97 ticker: abc
# stock_price: 52.1 ticker: abc
# stock_price: 45.55 ticker: abc
# stock_price: 57.9 ticker: abc
# stock_price: 65.93 ticker: abc
# stock_price: 53.94 ticker: abc
# stock_price: 79.46 ticker: abc
# stock_price: 56.36 ticker: abc
# stock_price: 55.44 ticker: abc
# stock_price: 52.65 ticker: abt
# stock_price: 44.48 ticker: abt
# stock_price: 57.97 ticker: abt
# stock_price: 55.02 ticker: abt
# stock_price: 51.28 ticker: abt
# stock_price: 54.5 ticker: abt
# stock_price: 57.11 ticker: abt
# stock_price: 50.45 ticker: abt
# stock_price: 45.93 ticker: abt
# stock_price: 42.78 ticker: abt
# stock_price: 40.86 ticker: abt
# stock_price: 45.61 ticker: abt
# stock_price: 56.3 ticker: abt
# stock_price: 42.92 ticker: abt
# stock_price: 58.6 ticker: ace
# stock_price: 57.24 ticker: ace
# stock_price: 59.98 ticker: ace
# stock_price: 41.04 ticker: ace
# stock_price: 42.76 ticker: ace
# stock_price: 39.1 ticker: ace
# stock_price: 67.52 ticker: aci
# stock_price: 11.93 ticker: aci
# stock_price: 25.11 ticker: aci
# stock_price: 30.78 ticker: aci
# stock_price: 38.4 ticker: aci
# stock_price: 34.52 ticker: aci
# stock_price: 30.08 ticker: aci
# stock_price: 33.93 ticker: aci
# stock_price: 51.09 ticker: aci
# stock_price: 46.39 ticker: aci
# stock_price: 41.15 ticker: aci
# stock_price: 42.81 ticker: acn
# stock_price: 29.98 ticker: acn
# stock_price: 36.77 ticker: acn
# stock_price: 28.57 ticker: acn
# stock_price: 25.31 ticker: acn
# stock_price: 33.87 ticker: acn
# stock_price: 26.2 ticker: acn
# stock_price: 39.1 ticker: acn
# stock_price: 28.36 ticker: acn
# stock_price: 33.81 ticker: acn
# stock_price: 27.89 ticker: acn
# stock_price: 28.57 ticker: acn
# stock_price: 32.21 ticker: acn
# stock_price: 25.05 ticker: acn
# stock_price: 24.44 ticker: acn
# stock_price: 41.24 ticker: acn
# stock_price: 25.51 ticker: acn
# stock_price: 32.96 ticker: acn
# stock_price: 35.39 ticker: acn
# stock_price: 31.4 ticker: acn
# stock_price: 22.54 ticker: adbe
# stock_price: 27.12 ticker: adbe
# stock_price: 66.58 ticker: adbe
# stock_price: 46.09 ticker: adbe
# stock_price: 63.67 ticker: adbe
# stock_price: 20.44 ticker: adbe
# stock_price: 22.32 ticker: adbe
# stock_price: 58.1 ticker: adbe
# stock_price: 38.04 ticker: adbe
# stock_price: 22.13 ticker: adbe
# stock_price: 45.04 ticker: adi
# stock_price: 34.47 ticker: adi
# stock_price: 35.92 ticker: adi
# stock_price: 34.61 ticker: adi
# stock_price: 35.92 ticker: adi
# stock_price: 45.03 ticker: adi
# stock_price: 36.88 ticker: adi
# stock_price: 35.67 ticker: adi
# stock_price: 38.5 ticker: adi
# stock_price: 50.5 ticker: adi
# stock_price: 34.75 ticker: adm
# stock_price: 40.85 ticker: adm
# stock_price: 21.23 ticker: adm
# stock_price: 22.65 ticker: adm
# stock_price: 15.66 ticker: adm
# stock_price: 23.71 ticker: adm
# stock_price: 37.02 ticker: adm
# stock_price: 16.81 ticker: adm
# stock_price: 32.96 ticker: adm
# stock_price: 27.94 ticker: adm
# stock_price: 35.88 ticker: adm
# stock_price: 14.48 ticker: adm
# stock_price: 34.9 ticker: adm
# stock_price: 24.5 ticker: adm
# stock_price: 16.28 ticker: adm
# stock_price: 34.57 ticker: adm
# stock_price: 45.98 ticker: adp
# stock_price: 45.7 ticker: adp
# stock_price: 50.7 ticker: adp
# stock_price: 37.59 ticker: adp
# stock_price: 45.17 ticker: adp
# stock_price: 44.48 ticker: adp
# stock_price: 38.56 ticker: adp
# stock_price: 47.52 ticker: adp
# stock_price: 49.23 ticker: adp
# stock_price: 48.47 ticker: adp
# stock_price: 39.96 ticker: adsk
# stock_price: 31.69 ticker: adsk
# stock_price: 39.4 ticker: adsk
# stock_price: 29.83 ticker: adsk
# stock_price: 18.44 ticker: adsk
# stock_price: 48.01 ticker: aee
# stock_price: 46.34 ticker: aee
# stock_price: 53.77 ticker: aee
# stock_price: 52.32 ticker: aee
# stock_price: 51.66 ticker: aee
# stock_price: 53.51 ticker: aee
# stock_price: 46.07 ticker: aee
# stock_price: 51.83 ticker: aee
# stock_price: 10.13 ticker: aeo
# stock_price: 9.73 ticker: aeo
# stock_price: 45.33 ticker: aep
# stock_price: 33.96 ticker: aep
# stock_price: 31.64 ticker: aep
# stock_price: 49.34 ticker: aep
# stock_price: 32.38 ticker: aep
# stock_price: 43.82 ticker: aep
# stock_price: 9.66 ticker: aes
# stock_price: 7.96 ticker: aes
# stock_price: 16.48 ticker: aes
# stock_price: 17.63 ticker: aes
# stock_price: 22.42 ticker: aes
# stock_price: 17.9 ticker: aes
# stock_price: 22.3 ticker: aes
# stock_price: 11.05 ticker: aes
# stock_price: 12.42 ticker: aes
# stock_price: 8.39 ticker: aes
# stock_price: 41.1 ticker: aet
# stock_price: 45.0 ticker: aet
# stock_price: 24.87 ticker: aet
# stock_price: 92.65 ticker: aet
# stock_price: 130.85 ticker: aet
# stock_price: 86.6 ticker: aet
# stock_price: 54.11 ticker: aet
# stock_price: 76.32 ticker: aet
# stock_price: 50.13 ticker: aet
# stock_price: 118.21 ticker: aet
# stock_price: 77.5 ticker: aet
# stock_price: 82.71 ticker: aet
# stock_price: 45.61 ticker: aet
# stock_price: 35.47 ticker: afl
# stock_price: 33.43 ticker: afl
# stock_price: 39.99 ticker: afl
# stock_price: 40.4 ticker: afl
# stock_price: 47.92 ticker: afl
# stock_price: 46.78 ticker: afl
# stock_price: 61.31 ticker: afl
# stock_price: 25.06 ticker: afl
# stock_price: 37.0 ticker: afl
# stock_price: 38.22 ticker: afl
# stock_price: 48.45 ticker: afl
# stock_price: 43.93 ticker: afl
# stock_price: 39.58 ticker: afl
# stock_price: 69.32 ticker: agn
# stock_price: 65.01 ticker: agn
# stock_price: 54.11 ticker: agn
# stock_price: 92.83 ticker: agn
# stock_price: 76.65 ticker: agn
# stock_price: 91.42 ticker: agn
# stock_price: 113.32 ticker: agn
# stock_price: 63.89 ticker: agn
# stock_price: 113.52 ticker: agn
# stock_price: 104.14 ticker: agn
# stock_price: 75.47 ticker: agn
# stock_price: 69.07 ticker: agn
# stock_price: 72.5 ticker: agn
# stock_price: 52.07 ticker: aig
# stock_price: 1.8 ticker: aig
# stock_price: 1.7 ticker: aig
# stock_price: 51.85 ticker: aig
# stock_price: 59.87 ticker: aig
# stock_price: 68.32 ticker: aig
# stock_price: 67.0 ticker: aig
# stock_price: 70.65 ticker: aig
# stock_price: 70.27 ticker: aig
# stock_price: 66.14 ticker: aig
# stock_price: 1.67 ticker: aig
# stock_price: 74.72 ticker: aig
# stock_price: 70.11 ticker: aig
# stock_price: 3.85 ticker: aig
# stock_price: 37.81 ticker: aig
# stock_price: 72.55 ticker: aig
# stock_price: 1.66 ticker: aig
# stock_price: 33.95 ticker: aiv
# stock_price: 38.95 ticker: aiv
# stock_price: 35.96 ticker: aiv
# stock_price: 39.96 ticker: aiv
# stock_price: 32.5 ticker: aiv
# stock_price: 36.36 ticker: aiv
# stock_price: 28.39 ticker: aiv
# stock_price: 59.81 ticker: aiv
# stock_price: 38.05 ticker: aiv
# stock_price: 61.6 ticker: aiv
# stock_price: 38.0 ticker: aiv
# stock_price: 40.65 ticker: aiv
# stock_price: 36.65 ticker: aiv
# <img src="data:image/png;base64,..." width="691">
# TotalDebtEquitymrq.csv
